# %% [markdown]
# Exploratory data analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Comment this if the data visualisations doesn't work on your side
# %matplotlib inline

plt.style.use('bmh')

# %% [markdown]
# AAPL

# %%
df = pd.read_csv('AAPL_full_dataset.csv')
df = df.set_index('rec_date')

# %%
df.head()
# Out:
#                  open       high        low      close       volume  weekday  \
# rec_date
# 2010-01-01  30.447144  30.478571  30.080000  30.104286   88102700.0        5
# 2010-01-02  30.447144  30.478571  30.080000  30.104286   88102700.0        6
# 2010-01-03  30.447144  30.478571  30.080000  30.104286   88102700.0        7
# 2010-01-04  30.490000  30.642857  30.340000  30.572857  123432400.0        1
# 2010-01-05  30.657143  30.798571  30.464285  30.625713  150476200.0        2
#
#             month  holiday  close_change  volume_change  ...  dj_abstract_neg  \
# rec_date                                                 ...
# 2010-01-01      1        1      0.000000            0.0  ...              0.0
# 2010-01-02      1        0      0.000000            0.0  ...              0.0
# 2010-01-03      1        0      0.000000            0.0  ...              0.0
# 2010-01-04      1        0      0.468571     35329700.0  ...              0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3651 entries, 2010-01-01 to 2019-12-30
# Data columns (total 38 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   open                       3651 non-null   float64
#  1   high                       3651 non-null   float64
#  2   low                        3651 non-null   float64
#  3   close                      3651 non-null   float64
#  4   volume                     3651 non-null   float64
#  5   weekday                    3651 non-null   int64
#  6   month                      3651 non-null   int64
#  7   holiday                    3651 non-null   int64
#  8   close_change               3651 non-null   float64
#  9   volume_change              3651 non-null   float64
#  10  price_gap                  3651 non-null   float64
#  11  is_closed_by_high          3651 non-null   int64
#  12  is_closed_by_low           3651 non-null   int64
# ...

# %% [markdown]
# As observed, there are no missing values for all variables.

# %%
# Divide data into price data and news data
price = df.iloc[:,:11].drop(columns = ['weekday','month','holiday'])
news = df.iloc[:,14:]

# %% [markdown]
# EDA for price data

# %%
price_var = price.columns
price_var
# Out:
# Index(['open', 'high', 'low', 'close', 'volume', 'close_change',
#        'volume_change', 'price_gap'],
#       dtype='object')

# %%
# Groupwide analysis
# Prices
# Histograms
price.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8)
# Boxplot
#Prices
plt.figure(figsize=(9, 8))
ax = sns.boxplot(data=price.iloc[:,:4], orient="h", palette="Set2")
#Others
for variable in ['volume', 'close_change','volume_change', 'price_gap']:
    plt.figure(figsize=(9, 4))
    ax = sns.boxplot(x=price[variable])

# %%
# Analysis on a single variable
print("Analysing: ", price_var[4])
# Describtive statistics
print(price[price_var[4]].describe())
# Distribution plot
plt.figure(figsize=(9, 8))
sns.distplot(price[price_var[4]], color='g', bins=50, hist_kws={'alpha': 0.4});
# Box plot
plt.figure(figsize=(9, 4))
ax = sns.boxplot(x=price[price_var[4]])
# Out:
# Analysing:  volume
# count    3.651000e+03
# mean     7.477711e+07
# std      5.853688e+07
# min      1.136200e+07
# 25%      3.171290e+07
# 50%      5.578930e+07
# 75%      1.009984e+08
# max      4.702495e+08
# Name: volume, dtype: float64

# %% [markdown]
# EDA for news data

# %%
# Groupwide analysis
# Histograms
news.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8);

# %%
# Heatmap
corr = news.corr().round(1)
plt.figure(figsize=(20, 20))
sns.heatmap(corr, annot = True, vmin=-1, vmax=1, center= 0, cmap= 'coolwarm', linewidths=1,annot_kws={"size": 10});

# %%
#boxplots
##divide data based on their mean to obtain better visualization
#small = news_qqq.columns[news_qqq.mean(axis = 0) < 10]
#large = news_qqq.columns[news_qqq.mean(axis = 0) >= 10]

for variable in news.columns[0:8]:
    plt.figure(figsize=(9, 4))
    ax = sns.boxplot(x=news[variable])

# %%
for variable in news.columns[8:16]:
    plt.figure(figsize=(9, 4))
    ax = sns.boxplot(x=news[variable])

# %%
for variable in news.columns[16:24]:
    plt.figure(figsize=(9, 4))
    ax = sns.boxplot(x=news[variable])
